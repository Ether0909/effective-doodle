# %% [markdown]
# <h2 id='part1'>Developer Survey 2017-Blog Post</h2>
#
# Purpose: curious about the backgroud of developers. I use 2017 stackover flow survey data to create the blog.
#
# Questions 1: What are the lcoation of developers globally?
# Question 2: What type are developers?
# Question 3: What are their education backgroud?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

df = pd.read_csv('./survey_results_public.csv')
df.head()
# Out:
#    Respondent                                       Professional  \
# 0           1                                            Student
# 1           2                                            Student
# 2           3                             Professional developer
# 3           4  Professional non-developer who sometimes write...
# 4           5                             Professional developer
#
#                 ProgramHobby         Country      University  \
# 0                  Yes, both   United States              No
# 1                  Yes, both  United Kingdom  Yes, full-time
# 2                  Yes, both  United Kingdom              No
# 3                  Yes, both   United States              No
# 4  Yes, I program as a hobby     Switzerland              No
#
#                          EmploymentStatus  \
# 0  Not employed, and not looking for work
# 1                      Employed part-time
# 2                      Employed full-time
# ...

# %% [markdown]
# <h3 id='q1'>Check rows and columns</h3>
#
# Provide the number of rows and columns in this dataset.

# %%
num_rows = df.shape[0] #Provide the number of rows in the dataset
num_cols = df.shape[1] #Provide the number of columns in the dataset

# %% [markdown]
# ### Missing value
#
#  Which columns had no missing values? And which columns have the most missing values?

# %%
no_nulls = set(df.columns[df.isnull().mean()==0])#Provide columns with 0 missing values.

# %%
most_missing_cols = set(df.columns[df.isnull().mean() > 0.75])#Provide columns with more than 75% of the values missing

# %% [markdown]
# ### Question 1
#
# **1.** Where are developers located?

# %%
count_vals = df.Country.value_counts()#Provide a pandas series of the counts for each Country

(count_vals[:10]/df.shape[0]).plot(kind="bar"); # The below bar chart of the proportion of the top 10 countries.
plt.title("Country");

# %% [markdown]
# Conclusion:More than 20% developers are from US, around 10% from India, 10% from UK.
#
# ### Question 2
#
# **2.** What type of developers there are?

# %%
status_vals = df.Professional.value_counts() #Provide a pandas series of the counts for each Professional status

(status_vals/df.shape[0]).plot(kind="bar");
# Below bar chart shows the proportion of individuals in each professional category
plt.title("Type of Developers");

# %% [markdown]
# Conclusion: More than 70% devlopers are preofessional or say full time. less than 30% are students or part time.
#
# ### Question 3
#
# **3.** What are education back groud of developers?

# %%
ed_vals = df.FormalEducation.value_counts()#Provide a pandas series of the counts for each FormalEducation status

(ed_vals/df.shape[0]).plot(kind="bar"); # Below bar chart of the proportion of individuals education backgroud
plt.title("Education Backgroud");

# %% [markdown]
# Conclusion: More than 40% developers are bachelor degree, more than 20% are master degree.
